# %%
import pandas as pd

# %%
df = pd.read_excel('test.xlsx', header = 1)
df = df.drop(78, axis=0)

# %%
df
# Out:
#     序号   姓名          学号        专业        行政班    平均绩点  平均绩点专业排名  平均绩点年级排名  \
# 0    1  李新浩  20185525.0  计算机科学与技术  19计算机卓越02  3.8817       6.0       6.0
# 1    2  李燕琴  20195633.0  计算机科学与技术  19计算机卓越02  3.9234       2.0       2.0
# 2    3   王征  20191618.0  计算机科学与技术  19计算机卓越01  3.9064       5.0       5.0
# 3    4  杨鑫隆  20194971.0  计算机科学与技术  19计算机卓越01  3.9101       4.0       4.0
# 4    5   佟璇  20191672.0  计算机科学与技术  19计算机卓越02  3.8801       7.0       7.0
# ..  ..  ...         ...       ...        ...     ...       ...       ...
# 73  74   赵碧  20194211.0  计算机科学与技术    19计算机04  3.5600      81.0      81.0
# 74  75  吕佳骏  20194105.0      信息安全   19信息安全01  3.5540       1.0      82.0
# 75  76  李渊科  20194289.0  计算机科学与技术    19计算机06  3.4910      94.0      95.0
# 76  77  王雅婷  20194096.0  计算机科学与技术    19计算机05  3.5394      83.0      84.0
# 77  78  张一帆  20194109.0  计算机科学与技术    19计算机02  3.5237      85.0      86.0
#
#     专业总人数    加分    综合绩点  综合绩点年级排名  综合绩点专业排名 是否获得初选资格
# 0   219.0  0.35  4.2317       1.0       1.0        是
# 1   219.0  0.30  4.2234       2.0       2.0        是
# 2   219.0  0.30  4.2064       3.0       3.0        是
# 3   219.0  0.25  4.1601       4.0       4.0        是
# 4   219.0  0.25  4.1301       5.0       5.0        是
# ..    ...   ...     ...       ...       ...      ...
# 73  219.0  0.00  3.5600      83.0      83.0       替补
# 74   44.0  0.00  3.5540      84.0       1.0       替补
# 75  219.0  0.05  3.5410      85.0      84.0       替补
# 76  219.0  0.00  3.5394      86.0      85.0       替补
# 77  219.0  0.00  3.5237      88.0      87.0       替补
#
# [78 rows x 14 columns]

# %%
df['平均绩点'].mean()
# Out:
# 3.710866666666667

# %%
df.loc[df.是否获得初选资格 == '是', '是否获得初选资格'].count()
# Out:
# 66

# %%
import sys
df.iloc[:20].to_csv(sys.stdout, sep='|')
# Out:
# |序号|姓名|学号|专业|行政班|平均绩点|平均绩点专业排名|平均绩点年级排名|专业总人数|加分|综合绩点|综合绩点年级排名|综合绩点专业排名|是否获得初选资格
# 0|1|李新浩|20185525.0|计算机科学与技术|19计算机卓越02|3.8817|6.0|6.0|219.0|0.35|4.2317|1.0|1.0|是
# 1|2|李燕琴|20195633.0|计算机科学与技术|19计算机卓越02|3.9234|2.0|2.0|219.0|0.3|4.2234|2.0|2.0|是
# 2|3|王征|20191618.0|计算机科学与技术|19计算机卓越01|3.9064|5.0|5.0|219.0|0.3|4.2064|3.0|3.0|是
# 3|4|杨鑫隆|20194971.0|计算机科学与技术|19计算机卓越01|3.9101|4.0|4.0|219.0|0.25|4.1601|4.0|4.0|是
# 4|5|佟璇|20191672.0|计算机科学与技术|19计算机卓越02|3.8801|7.0|7.0|219.0|0.25|4.1301|5.0|5.0|是
# 5|6|张鑫|20192997.0|计算机科学与技术|19计算机卓越02|3.7486|31.0|31.0|219.0|0.35|4.0986|6.0|6.0|是
# 6|7|张博|20194157.0|计算机科学与技术|19计算机卓越01|3.9301|1.0|1.0|219.0|0.15|4.0801|7.0|7.0|是
# 7|8|胡泰航|20192498.0|计算机科学与技术|19计算机卓越02|3.8307|13.0|13.0|219.0|0.2|4.0307|8.0|8.0|是
# 8|9|李放|20194056.0|计算机科学与技术|19计算机卓越02|3.8006|17.0|17.0|219.0|0.2|4.0006|9.0|9.0|是
# 9|10|张翀|20194159.0|计算机科学与技术|19计算机卓越02|3.7779|26.0|26.0|219.0|0.2|3.9779|10.0|10.0|是
# 10|11|唐圣昊|20194180.0|计算机科学与技术|19计算机卓越01|3.7958|18.0|18.0|219.0|0.15|3.9458|12.0|12.0|是
# 11|12|于卓浩|20194134.0|计算机科学与技术|19计算机卓越01|3.6924|46.0|46.0|219.0|0.25|3.9424|13.0|13.0|是
# 12|13|刘思霖|20192438.0|计算机科学与技术|19计算机卓越01|3.7321|38.0|38.0|219.0|0.2|3.9321|14.0|14.0|是
# 13|14|周逸群|20191583.0|计算机科学与技术|19计算机卓越02|3.7315|39.0|39.0|219.0|0.2|3.9315|15.0|15.0|是
# 14|15|张诗琦|20194313.0|计算机科学与技术|19计算机卓越02|3.7792|24.0|24.0|219.0|0.15|3.9292|16.0|16.0|是
# 15|16|谭诗婷|20191668.0|计算机科学与技术|19计算机06|3.6568|56.0|56.0|219.0|0.25|3.9068|17.0|17.0|是
# 16|17|杨旭峰|20192680.0|计算机科学与技术|19计算机卓越02|3.706|43.0|43.0|219.0|0.2|3.906|18.0|18.0|是
# 17|18|张书萌|20194283.0|计算机科学与技术|19计算机01|3.6455|63.0|63.0|219.0|0.25|3.8955|19.0|19.0|是
# 18|19|陶虹霖|20194115.0|计算机科学与技术|19计算机卓越01|3.7948|19.0|19.0|219.0|0.1|3.8948|20.0|20.0|是
# 19|20|王梓宇|20194195.0|计算机科学与技术|19计算机卓越01|3.743|33.0|33.0|219.0|0.15|3.893|21.0|21.0|是

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
issues = pd.DataFrame(data, columns=['number', 'title', 'labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    48632               DOC: GL08 errors in pandas.Timestamp
# 1    48631  DOC: Update documentation for date_range(), bd...
# 2    48630  Backport PR #48627 on branch 1.5.x (DOC: Last ...
# 3    48629  Backport PR #48619 on branch 1.5.x (REGR: Loc....
# 4    48628                       CI: Get rid of some warnings
# 5    48626  REGR: sort_value can not sort levels with non ...
# 6    48624   TYP: type all arguments with bool default values
# 7    48622      PERF: Improve performance for MultiIndex.isin
# 8    48621            PDEP-4: consistent parsing of datetimes
# 9    48620            REGR: Performance decrease in factorize
# 10   48618  TST: add test case for PeriodIndex in HDFStore...
# 11   48616  BUG: Fix metadata propagation in df.corr and d...
# 12   48615                             WIP: Multichar comment
# 13   48613  Revised the doc-string for _app_template to br...
# 14   48612                                  TYP: tighten Axis
# 15   48611           PERF: join/merge on subset of MultiIndex
# 16   48610  BUG: pandas.to_datetime fails to handle numpy....
# 17   48609          PERF: DatetimeIndex constructor from list
# 18   48608  REGR: assert_index_equal raising with non matc...
# 19   48607  BUG: MultiIndex.symmetric_difference not keepi...
# 20   48606    BUG: MultiIndex.difference not keeping ea dtype
# 21   48604  ENH: MultiIndex.intersection now keeping EA dt...
# 22   48603  PERF: Avoid fragmentation of DataFrame in read...
# 23   48602                CI: Matplotlib 3.6 broke our builds
# 24   48600              DOC: Fix version switcher in old docs
# 25   48599  DOC: Add deprecation infos to deprecated funct...
# 26   48598                 DOC: Add light/dark theme switcher
# 27   48597  DOC: include defaults into docs for true_value...
# 28   48596             ENH: make infer_datetime_format strict
# 29   48595  BUG: Large number of PerformanceWarnings when ...
#
#                                                labels state
# 0   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 1                                                  []  open
# 2   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 3   [{'id': 2822098, 'node_id': 'MDU6TGFiZWwyODIyM...  open
# 4   [{'id': 1628184320, 'node_id': 'MDU6TGFiZWwxNj...  open
# 5   [{'id': 32815646, 'node_id': 'MDU6TGFiZWwzMjgx...  open
# 6                                                  []  open
# 7   [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 8   [{'id': 4253279386, 'node_id': 'LA_kwDOAA0YD87...  open
# 9   [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 10                                                 []  open
# 11                                                 []  open
# 12                                                 []  open
# 13                                                 []  open
# 14                                                 []  open
# 15                                                 []  open
# 16  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 17                                                 []  open
# 18  [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 19  [{'id': 71268330, 'node_id': 'MDU6TGFiZWw3MTI2...  open
# 20  [{'id': 71268330, 'node_id': 'MDU6TGFiZWw3MTI2...  open
# 21  [{'id': 71268330, 'node_id': 'MDU6TGFiZWw3MTI2...  open
# 22  [{'id': 258745163, 'node_id': 'MDU6TGFiZWwyNTg...  open
# 23  [{'id': 2413328, 'node_id': 'MDU6TGFiZWwyNDEzM...  open
# 24  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 25  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 26  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 27                                                 []  open
# 28  [{'id': 211840, 'node_id': 'MDU6TGFiZWwyMTE4ND...  open
# 29  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
