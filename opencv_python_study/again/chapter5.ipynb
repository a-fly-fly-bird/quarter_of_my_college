# %%
# %matplotlib inline
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def show(img, title='Image'):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')  # 不显示坐标轴
    plt.title(title) # 图像题目
    plt.show()

# %% [markdown]
# # 缩放

# %% [markdown]
# 当缩小图像时，使用区域插值方式（INTER_AREA）能够得到最好的效果；当放大图像时，使用三次样条插值（INTER_CUBIC）方式和双线性插值（INTER_LINEAR）方式都能够取得较好的效果。

# %% [markdown]
# ## 通过dsize指定

# %%
img = cv2.imread('images/color.jpg')
show(img)

# %%
img.shape
# Out:
# (2400, 3840, 3)

# %%
rst = cv2.resize(img, (8000, 4000))
show(rst)

# %% [markdown]
# ## 通过fx, fy指定

# %%
rst = cv2.resize(img, None, fx=5, fy=3, interpolation=cv2.INTER_CUBIC)
show(rst)

# %% [markdown]
# # 翻转

# %%
show(cv2.flip(img, 0))

# %% [markdown]
# # 仿射

# %%
height, width=img.shape[:2]
x=100
y=200
M = np.float32([[1, 0, x], [0, 1, y]])
move=cv2.warpAffine(img, M, (width, height))
show(img)
show(move)
